# %%
import matplotlib.pyplot as plt

# Başarı oranı (örneğin, %80)
success_rate = 0.8

# Örnek sayısı
sample_sizes = [50, 100, 200,400]

# Başarı oranını kullanarak başarı sayıları elde etme
success_counts = [70,95,90,93.75]

# Çizgi grafiği oluşturma
plt.plot(sample_sizes, success_counts, marker='o', linestyle='-', color='b')
plt.title('Başarı Oranı ve Örnek Sayısı İlişkisi')
plt.xlabel('Örnek Sayısı')
plt.ylabel('Başarım Oranı')
plt.grid(True)
plt.show()
